# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavyasreegonuguntta/Skllentrix_intern/blob/main/Movie_recommendation_systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Movie recommendation systems project started")
# Out:
# Movie recommendation systems project started

# %%
# Movie Recommendation System (Content-Based Filtering)

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Sample movie data
movies = pd.DataFrame({
    'title': [
        'Avatar',
        'Titanic',
        'The Avengers',
        'Iron Man',
        'Interstellar'
    ],
    'genre': [
        'Action Adventure Sci-Fi',
        'Romance Drama',
        'Action Superhero Adventure',
        'Action Superhero Sci-Fi',
        'Sci-Fi Space Drama'
    ]
})

# Convert genres into TF-IDF vectors
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(movies['genre'])

# Calculate cosine similarity
similarity = cosine_similarity(tfidf_matrix)

# Recommendation function
def recommend(movie_name):
    idx = movies[movies['title'] == movie_name].index[0]

    scores = list(enumerate(similarity[idx]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)

    print(f"\nMovies similar to '{movie_name}':")
    for i in scores[1:4]:
        print(movies.iloc[i[0]]['title'])

# Test
recommend("Iron Man")
# Out:
# Movies similar to 'Iron Man':
# Avatar
# The Avengers
# Interstellar
